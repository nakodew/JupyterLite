# %%
from scipy.io import loadmat
def loaddata(path):
    data = loadmat(path)
    return data

# %%
import matplotlib.pyplot as plt
import scipy.io as sio
import numpy as np

# %%
def displayData(x):
    indexs = np.random.choice(x.shape[0],100)
    images = x[indexs]
    fig,axs = plt.subplots(10,10,figsize = (20,20))
    for row in range(10):
        for col in range(10):
            axs[row,col].matshow(images[row*10+col].reshape(20,20).T, cmap='gray_r')
    plt.xticks([])
    plt.yticks([])
    #plt.show()

# %%
x = sio.loadmat('ex3data1.mat')

# %%
type(x)
# Out:
# dict

# %%
x.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
raw_X = x['X']
raw_y = x['y']

# %%
displayData(raw_X)

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
def costFunction(theta,X,y,lamda):
    A = sigmoid(X@theta)
    first = y*np.log(A)
    second = (1-y) * np.log(1-A)
    reg = theta[1:] @ theta[1:] * (lamda / (2 * len(X)))
    return -np.sum(first + second) / len(X) + reg

# %%
def feedforward_propagation(theta, X, y, lamda):
    #reg = theta[1:] * (lamda / len(X))
    #reg = np.insert(reg,0,values=0,axis=0)
    #first = (X.T@(sigmoid(X@theta) - y)) / len(X)
    #return first + reg
    theta = np.matrix(theta)
    X = np.matrix(X)
    y = np.matrix(y)

# %%
def predict(a3):
    return label

# %%
def accuracy(a3):
    return acc
